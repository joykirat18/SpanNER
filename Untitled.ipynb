# %%
import pickle
# open pickle file
with open('results.pickle', 'rb') as f:
    results = pickle.load(f)

# %%
len(results)
# Out:
# 435

# %%
predicts = results[12][0]

# %%
import torch
pred_label_idx = torch.max(predicts, dim=-1)[1]

# %%
print(pred_label_idx)
# Out:
# tensor([0, 0, 0,  ..., 0, 0, 0], device='cuda:2')

# %%
for i in pred_label_idx[0]:
    print(i)
# Out:
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# tensor(0, device='cuda:2')
# ...
